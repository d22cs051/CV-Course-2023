# %% [markdown]
# # Train YOLO object detection model

# %%
# !pip -q install -U ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.9 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3090, 24257MiB)
# Setup complete ✅ (48 CPUs, 125.7 GB RAM, 186.6/200.3 GB disk)

# %%
import os
os.chdir(os.getcwd())

# %%
# !yolo train model=yolov8n.pt data="./datasets/deer_dataset.yml" epochs=100 imgsz=640 batch=10
# Out:
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.9 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3090, 24257MiB)
# ...
